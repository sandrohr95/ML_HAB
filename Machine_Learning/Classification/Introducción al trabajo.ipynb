# %% [markdown]
# # Predicción de Cancer de mama

# %% [markdown]
# ### Introducción al trabajo
# ![imagen.png](attachment:imagen.png)
#
#
# De todos los casos de cáncer, el cáncer de mama es uno bastante común. De hecho, en los Estados Unidos, el cáncer de mama es el cáncer más común diagnosticado en mujeres después del cáncer de pulmón que conduce a la muerte. El cáncer de mama puede ocurrir tanto en hombres como en mujeres, pero es mucho más común en las mujeres.
#
# Los avances en las pruebas de detección y el tratamiento han mejorado drásticamente las tasas de supervivencia desde 1989. Hay alrededor de 3,1 millones de supervivientes de cáncer de mama en los Estados Unidos (EE. UU.). La probabilidad de que una mujer muera de cáncer de mama es de alrededor de 1 en 37 o 2.7 por ciento. Pero incluso en 2021, se esperan alrededor de 252.710 nuevos diagnósticos de cáncer de mama en mujeres, y es probable que alrededor de 40.610 mujeres mueran a causa de la enfermedad. Las cifras han mejorado desde entonces, principalmente debido a la concientización sobre el cáncer de mama y al buen tratamiento.
#
# ### Contexto en España
# ![imagen-3.png](attachment:imagen-3.png)
# ### Adquisición de los datos
# El conjunto de datos etiquetado proviene de la Base de datos de cáncer de mama de Wisconsin disponible  en la biblioteca sklearn de Python.
# Dataset: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)
#
# ### Descripción de los datos
# Este trabajo surgió del deseo del Dr. Wolberg de diagnosticar con precisión las masas mamarias basándose únicamente en una aspiración con aguja fina (FNA). Identificó nueve características evaluadas visualmente de una muestra que consideró relevantes para el diagnóstico. En colaboración con el profesor Mangasarian y dos de sus estudiantes de posgrado, Rudy Setiono y Kristin Bennett, se construyó un clasificador utilizando el método multisuperficie (MSM) de separación de patrones en estas nueve características que diagnosticaron con éxito el 97% de los casos nuevos. El conjunto de datos resultante se conoce como datos de cáncer de mama de Wisconsin.
#
# http://pages.cs.wisc.edu/~olvi/uwmp/cancer.html
#
#
# ##### Objetivo
# Usaremos un flujo de trabajo ML para diagnosticar el cáncer como benigno (no se expande al resto del cuerpo) o maligno (se expande al resto del cuerpo). La idea es proporcionar un detección temprana del cancer para evitar su expansión
# ![imagen-4.png](attachment:imagen-4.png)
#
# ##### Objetivos académicos
# La idea de la primera clase es aprender a realizar una exploración exhaustiva de los datos. Posteriormente se aprenderá a aplicar técnicas de selección de características. Se evaluará el/los modelos aplicando y sin aplicar técnicas de Feature Selection y compararemos resultados.

# %% [markdown]
# ## Flujo de trabajo Machine Learning.
#
# Seguir todos los pasos necesarios para crear un flujo de trabajo para utilizar algoritmos de Machine Learning:
#
# 1º Lo primero será la lectura y exploración.
#
# 2º Menejo de técnicas de pre-procesamiento de datos:
#  - Evitar valores missing en el dataset
#  - Estandarización/Normalización de los datos (siempre y cuando sea necesario)
#  - Feature Selection. Aplicar algún/os método/s de selección de variables. La idea es entrenar el modelo con todas las características del dataset y evaluarlo, y después aplicar un método de selección de variables y volver a entrenar el modelo con las características seleccionadas y comparar resultados. Si se aplica más de un método de selección de variables se pueden comparar los resultados.
# NOTA: para fijar el número de características elegidas por el método habrá que justificar el porqué, es decir, habrá que escoger el número óptimo de características para elegir el mejor modelo.
#  - PCA (Principal Component Analysis). Esta vez aplicaremos un PCA sobre el dataset completo y compararemos los resultados obtenidos.
#
# 3º Selección del modelo:
# - Debemos de evaluar distintos modelos de clasificación y comparar sus resultados
#
# 4º Manejo de técnicas de hiperparametrización. Tenemos que saber aplicar al menos parametrización manual e hiperparametrización automática con el método GridSearch. Para definir el espacio de búsqueda de parámetros primero debemos de hacer un estudio previo del funcionamiento del algoritmo y de sus parámetros de entrada.
#
# 5º Evaluación del modelo. Debemos de conocer y saber aplicar distintas métricas para evaluar los modelos.
#
# 5.1º Además, se aplicará Cross-Validación para evaluar el modelo utilizando distintos fragmentos para entrenar y evaluar el modelo.
